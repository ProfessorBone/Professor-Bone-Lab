# %%
# Setup
# To be implemented during study

# %% [markdown]
# ## State Schema Design
#
# _To be filled during study_

# %%
# State schema implementation
# To be implemented during study

# %% [markdown]
# ## Experiments
#
# _To be filled during study_
