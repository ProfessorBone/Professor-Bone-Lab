# %%
# Setup
# To be implemented during study

# %% [markdown]
# ## Experiment 1: Pure Planner
#
# _To be filled during study_

# %%
# Pure planner implementation
# To be implemented during study

# %% [markdown]
# ## Experiment 2: Pure Orchestrator
#
# _To be filled during study_

# %%
# Pure orchestrator implementation
# To be implemented during study

# %% [markdown]
# ## Experiment 3: Planner + Orchestrator
#
# _To be filled during study_

# %%
# Combined system implementation
# To be implemented during study

# %% [markdown]
# ## Analysis
#
# _To be filled during study_
